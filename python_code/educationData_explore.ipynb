# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
os.chdir('./educationData')
os.getcwd()
# Out:
# '/media/livan/44B2A18BB2A18252/Users/Ivan/Documents/Others/misc/Machine_learning/python/educationData'

# %%
ls
# Out:
# EdStatsCountry.csv*         EdStatsEXCEL.xlsx*    educationData_explore.ipynb*
# EdStatsCountry-Series.csv*  EdStatsFootNote.csv*
# EdStatsData.csv*            EdStatsSeries.csv*

# %%
ctry_data = pd.read_csv('EdStatsCountry.csv')
ctry_data.head()
# Out:
#   Country Code   Short Name   Table Name                     Long Name  \
# 0          ABW        Aruba        Aruba                         Aruba
# 1          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 2          AGO       Angola       Angola   People's Republic of Angola
# 3          ALB      Albania      Albania           Republic of Albania
# 4          AND      Andorra      Andorra       Principality of Andorra
#
#   2-alpha code   Currency Unit  \
# 0           AW   Aruban florin
# 1           AF  Afghan afghani
# 2           AO  Angolan kwanza
# 3           AL    Albanian lek
# 4           AD            Euro
#
#                                        Special Notes  \
# 0  SNA data for 2000-2011 are updated from offici...
# 1  Fiscal year end: March 20; reporting period fo...
# 2  April 2013 database update: Based on IMF data,...
# 3                                                NaN
# 4                                                NaN
#
# ...
